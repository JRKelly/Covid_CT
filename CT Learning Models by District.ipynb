# %% [markdown]
# $\huge{\color{red}{\text{Connecticut District Learning Models,}}}$
# <br>
# <br>

# %%
import pandas
import numpy as np
from sodapy import Socrata
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ***
# <br>
# <br>
#
# $\huge{\color{blue}{\text{Fetch Table from CT DPH}}}$

# %%
client = Socrata("data.ct.gov", None)

results = client.get("5q7h-u2ac", limit=20000)

# Convert to pandas DataFrame
results_df = pandas.DataFrame.from_records(results)    
    
results_df[0:3]
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
#   district_code            district_name  \
# 0       0010011  Andover School District
# 1       0020011  Ansonia School District
# 2       0030011  Ashford School District
#
#                                grades_inperson_model grades_hybrid_model  \
# 0                      PK, K, g1, g2, g3, g4, g5, g6                 N/A
# 1  PK, K, g1, g2, g3, g4, g5, g6, g7, g8, g9, g10...                 N/A
# 2              PK, K, g1, g2, g3, g4, g5, g6, g7, g8                 N/A
#
#   grades_remote_model                predominant_model  \
# 0                 N/A  Most/All Grades Fully In-Person
# 1                 N/A  Most/All Grades Fully In-Person
# 2                 N/A  Most/All Grades Fully In-Person
#
#          organization_type                     reporting_period  \
# 0  Public School Districts  February 1, 2021 - February 5, 2021
# 1  Public School Districts  February 1, 2021 - February 5, 2021
# 2  Public School Districts  February 1, 2021 - February 5, 2021
#
#                update_date alliance_district school_start_date  \
# 0  2021-02-09T00:00:00.000               NaN               NaN
# 1  2021-02-09T00:00:00.000          Alliance               NaN
# 2  2021-02-09T00:00:00.000               NaN               NaN
#
#   percent_students_fully_remote total_number_students
# 0                           NaN                   NaN
# 1                           NaN                   NaN
# 2                           NaN                   NaN

# %% [markdown]
# $\huge{\color{blue}{\text{Predominant Model to 1,0}}}$

# %%
results_df = results_df.drop(['district_code', 'school_start_date', 'percent_students_fully_remote', 'total_number_students'], axis=1)
results_df['remote'] = np.where(results_df['predominant_model']=='Most/All Grades Fully Remote', 1, 0)
results_df[0:3]
# Out:
#              district_name                              grades_inperson_model  \
# 0  Andover School District                      PK, K, g1, g2, g3, g4, g5, g6
# 1  Ansonia School District  PK, K, g1, g2, g3, g4, g5, g6, g7, g8, g9, g10...
# 2  Ashford School District              PK, K, g1, g2, g3, g4, g5, g6, g7, g8
#
#   grades_hybrid_model grades_remote_model                predominant_model  \
# 0                 N/A                 N/A  Most/All Grades Fully In-Person
# 1                 N/A                 N/A  Most/All Grades Fully In-Person
# 2                 N/A                 N/A  Most/All Grades Fully In-Person
#
#          organization_type                     reporting_period  \
# 0  Public School Districts  February 1, 2021 - February 5, 2021
# 1  Public School Districts  February 1, 2021 - February 5, 2021
# 2  Public School Districts  February 1, 2021 - February 5, 2021
#
#                update_date alliance_district  remote
# 0  2021-02-09T00:00:00.000               NaN       0
# 1  2021-02-09T00:00:00.000          Alliance       0
# 2  2021-02-09T00:00:00.000               NaN       0

# %%
results_df['remote_num'] = results_df.grades_remote_model.apply(lambda x: len(x.split(',')))
results_df['hybrid_num'] = results_df.grades_hybrid_model.apply(lambda x: len(x.split(',')))
results_df['inperson_num'] = results_df.grades_inperson_model.apply(lambda x: len(x.split(',')))

# %%
#results_df['R'] = results_df.apply(lambda x: 'R' if x[10] > x[11] and x[10] > x[12] else ' ', axis=1)
#results_df['H'] = results_df.apply(lambda x: 'H' if x[11] > x[10] and x[11] > x[12] else ' ', axis=1)
#results_df['I'] = results_df.apply(lambda x: 'I' if x[12] > x[11] and x[12] > x[10] else ' ', axis=1)
#results_df['predom'] = results_df['R'] + results_df['H'] + results_df['I']
results_df['R'] = results_df.apply(lambda x: 1.0 if x[10] > x[11] and x[10] > x[12] else 0, axis=1)
results_df['H'] = results_df.apply(lambda x: 2.0 if x[11] > x[10] and x[11] > x[12] else 0, axis=1)
results_df['I'] = results_df.apply(lambda x: 3.0 if x[12] > x[10] and x[12] > x[11] else 0, axis=1)
results_df['predom'] = results_df[["R", "H", "I"]].max(axis=1)

# %%
temp_df = results_df[results_df.organization_type == 'Public School Districts']
temp_df['city'] = temp_df['district_name'].str.replace(' School District', ', CT')
temp_df[0:10]
#temp_df.to_csv("learning_models.csv")
# Out:
#                   district_name  \
# 0       Andover School District
# 1       Ansonia School District
# 2       Ashford School District
# 3          Avon School District
# 6   Barkhamsted School District
# 7        Berlin School District
# 8       Bethany School District
# 9        Bethel School District
# 11   Bloomfield School District
# 12       Bolton School District
#
#                                 grades_inperson_model  \
# 0                       PK, K, g1, g2, g3, g4, g5, g6
# 1   PK, K, g1, g2, g3, g4, g5, g6, g7, g8, g9, g10...
# 2               PK, K, g1, g2, g3, g4, g5, g6, g7, g8
# 3               PK, K, g1, g2, g3, g4, g5, g6, g7, g8
# 6                           K, g1, g2, g3, g4, g5, g6
# 7                           PK, K, g1, g2, g3, g4, g5
# 8                       PK, K, g1, g2, g3, g4, g5, g6
# 9               PK, K, g1, g2, g3, g4, g5, g6, g7, g8
# 11                                                 PK
# 12                              K, g1, g2, g3, g4, g5
#
#                                   grades_hybrid_model grades_remote_model  \
# 0                                                 N/A                 N/A
# 1                                                 N/A                 N/A
# 2                                                 N/A                 N/A
# 3                                                 N/A   g9, g10, g11, g12
# 6                                                 N/A                 N/A
# 7                       g6, g7, g8, g9, g10, g11, g12                 N/A
# 8                                                 N/A                 N/A
# 9                                   g9, g10, g11, g12                 N/A
# 11  K, g1, g2, g3, g4, g5, g6, g7, g8, g9, g10, g1...                 N/A
# 12                  PK, g6, g7, g8, g9, g10, g11, g12                 N/A
#
#                   predominant_model        organization_type  \
# 0   Most/All Grades Fully In-Person  Public School Districts
# 1   Most/All Grades Fully In-Person  Public School Districts
# 2   Most/All Grades Fully In-Person  Public School Districts
# 3   Most/All Grades Fully In-Person  Public School Districts
# 6   Most/All Grades Fully In-Person  Public School Districts
# 7   Most/All Grades Fully In-Person  Public School Districts
# 8   Most/All Grades Fully In-Person  Public School Districts
# 9   Most/All Grades Fully In-Person  Public School Districts
# 11           Most/All Grades Hybrid  Public School Districts
# 12           Most/All Grades Hybrid  Public School Districts
#
#                        reporting_period              update_date  \
# 0   February 1, 2021 - February 5, 2021  2021-02-09T00:00:00.000
# 1   February 1, 2021 - February 5, 2021  2021-02-09T00:00:00.000
# 2   February 1, 2021 - February 5, 2021  2021-02-09T00:00:00.000
# 3   February 1, 2021 - February 5, 2021  2021-02-09T00:00:00.000
# 6   February 1, 2021 - February 5, 2021  2021-02-09T00:00:00.000
# 7   February 1, 2021 - February 5, 2021  2021-02-09T00:00:00.000
# 8   February 1, 2021 - February 5, 2021  2021-02-09T00:00:00.000
# 9   February 1, 2021 - February 5, 2021  2021-02-09T00:00:00.000
# 11  February 1, 2021 - February 5, 2021  2021-02-09T00:00:00.000
# 12  February 1, 2021 - February 5, 2021  2021-02-09T00:00:00.000
#
#    alliance_district  remote  remote_num  hybrid_num  inperson_num    R    H  \
# 0                NaN       0           1           1             8  0.0  0.0
# 1           Alliance       0           1           1            14  0.0  0.0
# 2                NaN       0           1           1            10  0.0  0.0
# 3                NaN       0           4           1            10  0.0  0.0
# 6                NaN       0           1           1             7  0.0  0.0
# 7                NaN       0           1           7             7  0.0  0.0
# 8                NaN       0           1           1             8  0.0  0.0
# 9                NaN       0           1           4            10  0.0  0.0
# 11          Alliance       0           1          13             1  0.0  2.0
# 12               NaN       0           1           8             6  0.0  2.0
#
#       I  predom             city
# 0   3.0     3.0      Andover, CT
# 1   3.0     3.0      Ansonia, CT
# 2   3.0     3.0      Ashford, CT
# 3   3.0     3.0         Avon, CT
# 6   3.0     3.0  Barkhamsted, CT
# 7   0.0     0.0       Berlin, CT
# 8   3.0     3.0      Bethany, CT
# 9   3.0     3.0       Bethel, CT
# 11  0.0     2.0   Bloomfield, CT
# 12  0.0     2.0       Bolton, CT

# %% [markdown]
# $\huge{\color{blue}{\text{Select Districts}}}$

# %%
urban_df = results_df.dropna(subset=["alliance_district"])
#urban_df = results_df[results_df.alliance_district.isnull()]
#urban_df = urban_df[urban_df.organization_type == 'Public Charter School Districts']
urban_df[urban_df.district_name == "Norwalk School District"]
# Out:
#                 district_name      grades_inperson_model  \
# 147   Norwalk School District  PK, K, g1, g2, g3, g4, g5
# 432   Norwalk School District  PK, K, g1, g2, g3, g4, g5
# 717   Norwalk School District  PK, K, g1, g2, g3, g4, g5
# 1002  Norwalk School District  PK, K, g1, g2, g3, g4, g5
# 1287  Norwalk School District  PK, K, g1, g2, g3, g4, g5
# 1572  Norwalk School District  PK, K, g1, g2, g3, g4, g5
# 1857  Norwalk School District  PK, K, g1, g2, g3, g4, g5
# 2142  Norwalk School District  PK, K, g1, g2, g3, g4, g5
# 2427  Norwalk School District  PK, K, g1, g2, g3, g4, g5
# 2712  Norwalk School District  PK, K, g1, g2, g3, g4, g5
# 2997  Norwalk School District  PK, K, g1, g2, g3, g4, g5
# 3282  Norwalk School District  PK, K, g1, g2, g3, g4, g5
# 3567  Norwalk School District  PK, K, g1, g2, g3, g4, g5
# 3852  Norwalk School District  PK, K, g1, g2, g3, g4, g5
# 4137  Norwalk School District  PK, K, g1, g2, g3, g4, g5
# 4422  Norwalk School District  PK, K, g1, g2, g3, g4, g5
# 4707  Norwalk School District  PK, K, g1, g2, g3, g4, g5
# 4992  Norwalk School District  PK, K, g1, g2, g3, g4, g5
# 5277  Norwalk School District  PK, K, g1, g2, g3, g4, g5
# 5563  Norwalk School District                        N/A
#
#                 grades_hybrid_model grades_remote_model  \
# 147   g6, g7, g8, g9, g10, g11, g12                 N/A
# 432   g6, g7, g8, g9, g10, g11, g12                 N/A
# 717   g6, g7, g8, g9, g10, g11, g12                 N/A
# 1002  g6, g7, g8, g9, g10, g11, g12                 N/A
# 1287  g6, g7, g8, g9, g10, g11, g12                 N/A
# 1572  g6, g7, g8, g9, g10, g11, g12                 N/A
# 1857  g6, g7, g8, g9, g10, g11, g12                 N/A
# 2142  g6, g7, g8, g9, g10, g11, g12                 N/A
# 2427  g6, g7, g8, g9, g10, g11, g12                 N/A
# 2712  g6, g7, g8, g9, g10, g11, g12                 N/A
# 2997  g6, g7, g8, g9, g10, g11, g12                 N/A
# 3282  g6, g7, g8, g9, g10, g11, g12                 N/A
# 3567  g6, g7, g8, g9, g10, g11, g12                 N/A
# 3852  g6, g7, g8, g9, g10, g11, g12                 N/A
# 4137  g6, g7, g8, g9, g10, g11, g12                 N/A
# 4422  g6, g7, g8, g9, g10, g11, g12                 N/A
# 4707  g6, g7, g8, g9, g10, g11, g12                 N/A
# 4992  g6, g7, g8, g9, g10, g11, g12                 N/A
# 5277  g6, g7, g8, g9, g10, g11, g12                 N/A
# 5563                            N/A                 N/A
#
#                     predominant_model        organization_type  \
# 147   Most/All Grades Fully In-Person  Public School Districts
# 432   Most/All Grades Fully In-Person  Public School Districts
# 717   Most/All Grades Fully In-Person  Public School Districts
# 1002  Most/All Grades Fully In-Person  Public School Districts
# 1287  Most/All Grades Fully In-Person  Public School Districts
# 1572  Most/All Grades Fully In-Person  Public School Districts
# 1857  Most/All Grades Fully In-Person  Public School Districts
# 2142  Most/All Grades Fully In-Person  Public School Districts
# 2427      Most Grades Fully In-Person  Public School Districts
# 2712                              NaN  Public School Districts
# 2997                              NaN  Public School Districts
# 3282                              NaN  Public School Districts
# 3567                              NaN  Public School Districts
# 3852                              NaN  Public School Districts
# 4137                              NaN  Public School Districts
# 4422                              NaN  Public School Districts
# 4707                              NaN  Public School Districts
# 4992                              NaN  Public School Districts
# 5277                              NaN  Public School Districts
# 5563                              NaN  Public School Districts
#
#                              reporting_period              update_date  \
# 147       February 1, 2021 - February 5, 2021  2021-02-09T00:00:00.000
# 432       January 25, 2021 - January 29, 2021  2021-02-03T00:00:00.000
# 717       January 18, 2021 - January 22, 2021  2021-01-27T00:00:00.000
# 1002      January 11, 2021 - January 15, 2021  2021-01-19T00:00:00.000
# 1287        January 4, 2021 - January 8, 2021  2021-01-12T00:00:00.000
# 1572    December 14, 2020 - December 18, 2020  2020-12-23T00:00:00.000
# 1857     December 7, 2020 - December 11, 2020  2020-12-16T00:00:00.000
# 2142     November 30, 2020 - December 4, 2020  2020-12-09T00:00:00.000
# 2427    November 16, 2020 - November 20, 2020  2020-11-25T00:00:00.000
# 2712     November 9, 2020 - November 13, 2020  2020-11-19T00:00:00.000
# 2997      November 2, 2020 - November 6, 2020  2020-11-12T00:00:00.000
# 3282      October 26, 2020 - October 30, 2020  2020-11-05T00:00:00.000
# 3567      October 19, 2020 - October 23, 2020  2020-10-29T00:00:00.000
# 3852      October 12, 2020 - October 16, 2020  2020-10-22T00:00:00.000
# 4137        October 5, 2020 - October 9, 2020  2020-10-15T00:00:00.000
# 4422     September 28, 2020 - October 2, 2020  2020-10-08T00:00:00.000
# 4707  September 21, 2020 - September 25, 2020  2020-10-01T00:00:00.000
# 4992  September 14, 2020 - September 18, 2020  2020-09-24T00:00:00.000
# 5277   September 7, 2020 - September 11, 2020  2020-09-17T00:00:00.000
# 5563      August 31, 2020 - September 4, 2020  2020-09-15T00:00:00.000
#
#      alliance_district  remote  remote_num  hybrid_num  inperson_num    R  \
# 147           Alliance       0           1           7             7  0.0
# 432           Alliance       0           1           7             7  0.0
# 717           Alliance       0           1           7             7  0.0
# 1002          Alliance       0           1           7             7  0.0
# 1287          Alliance       0           1           7             7  0.0
# 1572          Alliance       0           1           7             7  0.0
# 1857          Alliance       0           1           7             7  0.0
# 2142          Alliance       0           1           7             7  0.0
# 2427          Alliance       0           1           7             7  0.0
# 2712          Alliance       0           1           7             7  0.0
# 2997          Alliance       0           1           7             7  0.0
# 3282          Alliance       0           1           7             7  0.0
# 3567          Alliance       0           1           7             7  0.0
# 3852          Alliance       0           1           7             7  0.0
# 4137          Alliance       0           1           7             7  0.0
# 4422          Alliance       0           1           7             7  0.0
# 4707          Alliance       0           1           7             7  0.0
# 4992          Alliance       0           1           7             7  0.0
# 5277          Alliance       0           1           7             7  0.0
# 5563          Alliance       0           1           1             1  0.0
#
#         H    I  predom
# 147   0.0  0.0     0.0
# 432   0.0  0.0     0.0
# 717   0.0  0.0     0.0
# 1002  0.0  0.0     0.0
# 1287  0.0  0.0     0.0
# 1572  0.0  0.0     0.0
# 1857  0.0  0.0     0.0
# 2142  0.0  0.0     0.0
# 2427  0.0  0.0     0.0
# 2712  0.0  0.0     0.0
# 2997  0.0  0.0     0.0
# 3282  0.0  0.0     0.0
# 3567  0.0  0.0     0.0
# 3852  0.0  0.0     0.0
# 4137  0.0  0.0     0.0
# 4422  0.0  0.0     0.0
# 4707  0.0  0.0     0.0
# 4992  0.0  0.0     0.0
# 5277  0.0  0.0     0.0
# 5563  0.0  0.0     0.0

# %%
districtlist = urban_df.district_name.unique().tolist()
districtlist
# Out:
# ['Ansonia School District',
#  'Bloomfield School District',
#  'Bridgeport School District',
#  'Bristol School District',
#  'Danbury School District',
#  'Derby School District',
#  'East Hartford School District',
#  'East Haven School District',
#  'East Windsor School District',
#  'Groton School District',
#  'Hamden School District',
#  'Hartford School District',
#  'Killingly School District',
#  'Manchester School District',
#  'Meriden School District',
#  'Middletown School District',
#  'Naugatuck School District',
#  'New Britain School District',
#  'New Haven School District',
#  'New London School District',
#  'Norwalk School District',
#  'Norwich School District',
#  'Putnam School District',
#  'Stamford School District',
#  'Thompson School District',
#  'Torrington School District',
#  'Vernon School District',
#  'Waterbury School District',
#  'West Haven School District',
#  'Winchester School District',
#  'Windham School District',
#  'Windsor School District',
#  'Windsor Locks School District']

# %%
bport_df = urban_df[urban_df['district_name'] == 'Bridgeport School District'].sort_values(by='update_date')
#bport_df

# %%
datalist = []
for district in districtlist:
    df = urban_df[urban_df['district_name'] == district].sort_values(by='update_date')
    datalist.append(df['predom'].tolist())
data = np.array(datalist)
#data

# %%
labels = []
for district in districtlist:
    labels.append(district.replace(' School District', ''))
labels
# Out:
# ['Ansonia',
#  'Bloomfield',
#  'Bridgeport',
#  'Bristol',
#  'Danbury',
#  'Derby',
#  'East Hartford',
#  'East Haven',
#  'East Windsor',
#  'Groton',
#  'Hamden',
#  'Hartford',
#  'Killingly',
#  'Manchester',
#  'Meriden',
#  'Middletown',
#  'Naugatuck',
#  'New Britain',
#  'New Haven',
#  'New London',
#  'Norwalk',
#  'Norwich',
#  'Putnam',
#  'Stamford',
#  'Thompson',
#  'Torrington',
#  'Vernon',
#  'Waterbury',
#  'West Haven',
#  'Winchester',
#  'Windham',
#  'Windsor',
#  'Windsor Locks']

# %%
fig, ax = plt.subplots(figsize=(30,30))
#data = np.array([bport_df['predom'].tolist()])

weeks = []
for week in bport_df['update_date'].tolist():
    weeks.append(week[5:10])

#districtlist = districtlist.insert(0, ' ')
    
im = ax.imshow(data)
ax.set_xticks(np.arange(len(weeks)))
ax.set_yticks(np.arange(len(labels)+1))
ax.set_xticklabels(weeks)
ax.set_yticklabels(labels)
plt.setp(ax.get_xticklabels(), rotation=45, size = 10, ha="right",
         rotation_mode="anchor")

#name = bport_df['district_name'].mode()[0]
#ax.set_title(name)
#plt.legend(bbox_to_anchor=(1,1), loc="lower right")

values = np.unique(data.ravel())
colors = [ im.cmap(im.norm(value)) for value in values]
# create a patch (proxy artist) for every color 
import matplotlib.patches as mpatches
models = ['no dominant model', 'most grades remote', 'most grades hybrid', 'most grades in person']
patches = [ mpatches.Patch(color=colors[i], label="{l}".format(l=models[i]) ) for i in range(len(models)) ]
# put those patched as legend-handles into the legend
plt.legend(handles=patches, bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0. )


#fig.tight_layout()
plt.savefig('alliance.png')
plt.show()
